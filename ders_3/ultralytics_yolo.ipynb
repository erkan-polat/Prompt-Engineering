# %%
# !pip install ultralytics torch torchvision torchaudio
# Out:
# ...
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 2.4.0
#     Uninstalling torch-2.4.0:
#       Successfully uninstalled torch-2.4.0
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.19.0
#     Uninstalling torchvision-0.19.0:
#       Successfully uninstalled torchvision-0.19.0
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.4.0
#     Uninstalling torchaudio-2.4.0:
#       Successfully uninstalled torchaudio-2.4.0
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fairseq 0.12.2 requires hydra-core<1.1,>=1.0.7, but you have hydra-core 1.3.2 which is incompatible.
# fairseq 0.12.2 requires omegaconf<2.1, but you have omegaconf 2.3.0 which is incompatible.
# ...

# %%
# !pip install --upgrade pip
# Out:
# ...
#   Using cached pip-24.2-py3-none-any.whl (1.8 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 21.2.3
#     Uninstalling pip-21.2.3:
#       Successfully uninstalled pip-21.2.3
# ERROR: Could not install packages due to an OSError: [WinError 5] Erişim engellendi: 'C:\\Users\\er_po\\AppData\\Local\\Temp\\pip-uninstall-ts6fyunc\\pip.exe'
# Consider using the `--user` option or check the permissions.

# %%
from ultralytics import YOLO

# Load a pretrained model Yolo11x.pt
model = YOLO(f'yolo11m.pt')

# %%
# Define path to image file or video file
source = "image/1.jpg" # "test.mp4"

# Run inference on the source
results = model(source, stream = False, conf = 0.45, show = True, save = True, device = 'mps')

print(results)
# Out:
# image 1/1 c:\Users\er_po\Desktop\Prompt Engineering\ders_3_dev\image\1.jpg: 384x640 (no detections), 226.5ms
# Speed: 2.8ms preprocess, 226.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\predict5
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %%
# Define path to image file or video file
source2 = "image/2.jpg" # "test.mp4"

# Run inference on the source
results = model(source2, stream = False, conf = 0.45, show = True, save = True, device = 'mps')

print(results)
# Out:
# image 1/1 c:\Users\er_po\Desktop\Prompt Engineering\ders_3_dev\image\2.jpg: 384x640 3 persons, 1 laptop, 227.1ms
# Speed: 6.0ms preprocess, 227.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\predict5
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %%
# Define path to image file or video file
source3 = "image/3.jpg" # "test.mp4"

# Run inference on the source
results = model(source3, stream = False, conf = 0.45, show = True, save = True, device = 'mps')

print(results)
# Out:
# image 1/1 c:\Users\er_po\Desktop\Prompt Engineering\ders_3_dev\image\3.jpg: 384x640 1 mouse, 1 keyboard, 194.7ms
# Speed: 0.0ms preprocess, 194.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\predict5
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %%
# Define path to image file or video file
source4 = "image/4.jpg" # "test.mp4"

# Run inference on the source
results = model(source4, stream = False, conf = 0.45, show = True, save = True, device = 'mps')

print(results)
# Out:
# image 1/1 c:\Users\er_po\Desktop\Prompt Engineering\ders_3_dev\image\4.jpg: 384x640 1 keyboard, 243.9ms
# Speed: 0.0ms preprocess, 243.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\predict5
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %%
# Define path to image file or video file
source5 = "image/5.jpg" # "test.mp4"

# Run inference on the source
results = model(source5, stream = False, conf = 0.45, show = True, save = True, device = 'mps')

print(results)
# Out:
# image 1/1 c:\Users\er_po\Desktop\Prompt Engineering\ders_3_dev\image\5.jpg: 384x640 1 cell phone, 199.8ms
# Speed: 0.0ms preprocess, 199.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\predict5
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %%
# Define path to image file or video file
source6 = "image/6.jpg" # "test.mp4"

# Run inference on the source
results = model(source6, stream = False, conf = 0.45, show = True, save = True, device = 'mps')

print(results)
# Out:
# image 1/1 c:\Users\er_po\Desktop\Prompt Engineering\ders_3_dev\image\6.jpg: 384x640 (no detections), 201.7ms
# Speed: 5.7ms preprocess, 201.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\predict5
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %%
# Define path to image file or video file
source7 = "image/7.jpg" # "test.mp4"

# Run inference on the source
results = model(source7, stream = False, conf = 0.45, show = True, save = True, device = 'mps')

print(results)
# Out:
# image 1/1 c:\Users\er_po\Desktop\Prompt Engineering\ders_3_dev\image\7.jpg: 384x640 8 books, 210.0ms
# Speed: 2.9ms preprocess, 210.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\predict5
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %%
# Define path to image file or video file
source8 = "image/8.jpg" # "test.mp4"

# Run inference on the source
results = model(source8, stream = False, conf = 0.45, show = True, save = True, device = 'mps')

print(results)
# Out:
# image 1/1 c:\Users\er_po\Desktop\Prompt Engineering\ders_3_dev\image\8.jpg: 384x640 1 person, 1 cell phone, 241.6ms
# Speed: 6.3ms preprocess, 241.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\predict5
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %%
# Define path to image file or video file
source9 = "image/9.jpg" # "test.mp4"

# Run inference on the source
results = model(source9, stream = False, conf = 0.45, show = True, save = True, device = 'mps')

print(results)
# Out:
# image 1/1 c:\Users\er_po\Desktop\Prompt Engineering\ders_3_dev\image\9.jpg: 384x640 1 person, 1 mouse, 1 cell phone, 234.9ms
# Speed: 0.0ms preprocess, 234.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\predict5
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %%
# Define path to image file or video file
source10 = "image/10.jpg" # "test.mp4"

# Run inference on the source
results = model(source10, stream = False, conf = 0.45, show = True, save = True, device = 'mps')

print(results)
# Out:
# image 1/1 c:\Users\er_po\Desktop\Prompt Engineering\ders_3_dev\image\10.jpg: 384x640 1 book, 243.1ms
# Speed: 0.0ms preprocess, 243.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\predict5
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %%
import cv2

from ultralytics import YOLO

# Load the YOLO model
model = YOLO(f'yolo11m.pt')

# Open the video file
video_path = "video/1.mp4"
cap = cv2.VideoCapture(video_path)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLO inference on the frame
        results = model(frame, device = 'mps')

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLO Inference", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 person, 6 books, 260.3ms
# Speed: 3.0ms preprocess, 260.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 books, 275.6ms
# Speed: 3.5ms preprocess, 275.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 7 books, 248.2ms
# Speed: 3.1ms preprocess, 248.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 7 books, 254.8ms
# Speed: 3.0ms preprocess, 254.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 books, 257.9ms
# Speed: 3.2ms preprocess, 257.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 books, 265.5ms
# Speed: 2.0ms preprocess, 265.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 books, 245.2ms
# ...
